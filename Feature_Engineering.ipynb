# %% [markdown]
# <a href="https://colab.research.google.com/github/Seenuprime/Certificates/blob/main/Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv(r'cleaned_df.csv')
df
# Out:
#         CustGender   CustLocation  CustAccountBalance TransactionDate  \
# 0                F     JAMSHEDPUR            17819.05          2/8/16
# 1                M        JHAJJAR             2270.69          2/8/16
# 2                F         MUMBAI            17874.44          2/8/16
# 3                F         MUMBAI           866503.21          2/8/16
# 4                F    NAVI MUMBAI             6714.43          2/8/16
# ...            ...            ...                 ...             ...
# 1047311          M      NEW DELHI             7635.19         18/9/16
# 1047312          M         NASHIK            27311.42         18/9/16
# 1047313          M      HYDERABAD           221757.06         18/9/16
# 1047314          M  VISAKHAPATNAM            10117.87         18/9/16
# 1047315          M           PUNE            75734.42         18/9/16
#
#          TransactionTime  TransactionAmount (INR)
# 0                 143207                     25.0
# ...

# %%
df.drop(columns=['TransactionDate', 'TransactionTime'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['CustGender'] = encoder.fit_transform(df['CustGender'])

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.iloc[:, [2, 5]] = scaler.fit_transform(df.iloc[:, [2, 5]])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer(
    transformers=[
        ('encode', CountVectorizer(), 'CustLocation')
    ],
    remainder='passthrough'
)

# %%
transformed_data = ct.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in _hstack(self, Xs)
#     829                 # dtype conversion if necessary.
# --> 830                 converted_Xs = [
#     831                     check_array(X, accept_sparse=True, force_all_finite=False)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in <listcomp>(.0)
#     830                 converted_Xs = [
# --> 831                     check_array(X, accept_sparse=True, force_all_finite=False)
#     832                     for X in Xs
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047316 entries, 0 to 1047315
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   CustGender               1047316 non-null  int64
#  1   CustLocation             1047316 non-null  object
#  2   CustAccountBalance       1047316 non-null  float64
#  3   TransactionDate          1047316 non-null  object
#  4   TransactionTime          1047316 non-null  int64
#  5   TransactionAmount (INR)  1047316 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 47.9+ MB
